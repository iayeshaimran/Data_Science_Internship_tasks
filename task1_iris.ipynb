# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df['species'] = iris.target

print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x='sepal length (cm)',
    y='sepal width (cm)',
    hue='species',
    data=df
)

plt.title("Scatter Plot of Sepal Length vs Width")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.histplot(df['petal length (cm)'], bins=20)

plt.title("Histogram of Petal Length")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(data=df)

plt.title("Box Plot of Iris Features")
plt.xticks(rotation=45)

plt.show()

# %%
# Conclusion

print("""
Conclusion:

1. Iris dataset clean aur balanced hai.
2. Scatter plot se variables ke relationships samajh aaye.
3. Histogram ne petal length ki distribution show ki.
4. Box plot ne spread aur possible outliers identify karne mein help ki.
5. Dataset visualization se analysis easy ho gaya.
""")
# Out:
# Conclusion:
#
# 1. Iris dataset clean aur balanced hai.
# 2. Scatter plot se variables ke relationships samajh aaye.
# 3. Histogram ne petal length ki distribution show ki.
# 4. Box plot ne spread aur possible outliers identify karne mein help ki.
# 5. Dataset visualization se analysis easy ho gaya.
